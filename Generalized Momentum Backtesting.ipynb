# %%
import MomVectorBacktester as Mom

# %%
# Initialize backtester class for Gold Symbol w/ Start and End Date.  $100000 to invest and a 0.0% Cost per Transaction
mombt = Mom.MomVectorBacktester('XAU=', '2010-1-1', '2019-12-31', 10000, 0.0)

# %%
# Run strategy with 3 day momentum
mombt.run_strategy(momentum=3)
# Out:
# /Users/matt/Desktop/Development/learning/oreilly/python_for_algorithmic_trading/MomVectorBacktester.py:72: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   # data['strategy'][trades] -= self.tc
# ...

# %%
mombt.plot_results()

# %%
# Initialize backtester class for Gold Symbol w/ Start and End Date.  $100000 to invest and a 0.1% per trade Cost per Transaction
mombt = Mom.MomVectorBacktester('XAU=', '2010-1-1', '2019-12-31', 10000, 0.001)

# %%
# Run strategy with 3 day momentum
mombt.run_strategy(momentum=3)
# Out:
# /Users/matt/Desktop/Development/learning/oreilly/python_for_algorithmic_trading/MomVectorBacktester.py:72: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   # data['strategy'][trades] -= self.tc
# ...

# %%
mombt.plot_results()

# %%
# When there is a cost per transaction, this strategy loses most of its performance
