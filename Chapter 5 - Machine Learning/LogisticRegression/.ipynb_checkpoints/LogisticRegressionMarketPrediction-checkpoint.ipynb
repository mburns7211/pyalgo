# %%
import numpy as np
import pandas as pd

# %%
symbol = 'GLD'

# %%
raw = pd.read_csv('http://hilpisch.com/pyalgo_eikon_eod_data.csv', index_col=0, parse_dates=True).dropna()

# %%
data = pd.DataFrame(raw[symbol])

# %%
data.rename(columns={symbol: 'price'}, inplace=True)

# %%
data['return'] = np.log(data['price'] / data['price'].shift(1))

# %%
data.dropna(inplace=True)

# %%
lags = 3

# %%
cols = []
for lag in range(1, lags + 1):
    col = f'lag_{lag}'
    data[col] = data['return'].shift(lag)
    cols.append(col)

# %%
from sklearn.metrics import accuracy_score
from sklearn import linear_model

# %%
lm = linear_model.LogisticRegression(C=1e7, solver='lbfgs', multi_class='auto', max_iter=1000) # instantiates model using C value that gives less weight to regulization term

# %%
data.dropna(inplace=True)

# %%
lm.fit(data[cols], np.sign(data['return'])) # fits model based on sign of the returns to be predicted
# Out:
# /home/matt/dev/pyalgo/venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(C=10000000.0, max_iter=1000, multi_class='auto')

# %%
data['prediction'] = lm.predict(data[cols])

# %%
data['prediction'].value_counts() # counts of long or short positions predicts
# Out:
# prediction
#  1.0    1975
# -1.0     537
# Name: count, dtype: int64

# %%
hits = np.sign(data['return'].iloc[lags:] * data['prediction'].iloc[lags:]).value_counts() # calculate if predictions were correct

# %%
hits
# Out:
#  1.0    1344
# -1.0    1153
#  0.0      12
# Name: count, dtype: int64

# %%
accuracy_score(data['prediction'], np.sign(data['return']))
# Out:
# 0.5362261146496815

# %%
data['strategy'] = data['prediction'] * data['return']

# %%
# gross performance is much higher when the passive benchmark investment

# %%
data[['return', 'strategy']].cumsum().apply(np.exp).plot(figsize=(10,6))
# Out:
# <Axes: xlabel='Date'>

# %%
# increase lags to 5

# %%
lags = 5

# %%
cols = []
for lag in range(1, lags + 1):
    col = f'lag_{lag}'
    data[col] = data['return'].shift(lag)
    cols.append(col)

# %%
lm = linear_model.LogisticRegression(C=1e7, solver='lbfgs', multi_class='auto', max_iter=1000) # instantiates model using C value that gives less weight to regulization term

# %%
data.dropna(inplace=True)

# %%
lm.fit(data[cols], np.sign(data['return'])) # fits model based on sign of the returns to be predicted
# Out:
# /home/matt/dev/pyalgo/venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(C=10000000.0, max_iter=1000, multi_class='auto')

# %%
data['prediction'] = lm.predict(data[cols])

# %%
data['prediction'].value_counts() # counts of long or short positions predicts
# Out:
# prediction
#  1.0    1973
# -1.0     529
# Name: count, dtype: int64

# %%
hits = np.sign(data['return'].iloc[lags:] * data['prediction'].iloc[lags:]).value_counts() # calculate if predictions were correct

# %%
hits
# Out:
#  1.0    1322
# -1.0    1163
#  0.0      12
# Name: count, dtype: int64

# %%
accuracy_score(data['prediction'], np.sign(data['return']))
# Out:
# 0.5291766586730615

# %%
data['strategy'] = data['prediction'] * data['return']

# %%
data[['return', 'strategy']].cumsum().apply(np.exp).plot(figsize=(10,6))
# Out:
# <Axes: xlabel='Date'>

# %%
# increasing lags 3 to 5 decreases the hit accuracy but increases the gross performance
